# %%
import ratinabox
from ratinabox import *

import matplotlib.pyplot as plt 

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(ratinabox.__file__)
# Out:
# /Users/tomgeorge/opt/anaconda3/lib/python3.9/site-packages/ratinabox-0.1-py3.9.egg/ratinabox/__init__.py

# %%
Env = Environment(params={'dimensionality':'2D'})
Ag = Agent(Env)
Ag.import_trajectory(dataset="sargolini")
# Out:
# Importing Sargolini locomotion dataset.
# Please cite Sargolini et al. (2006) DOI:10.1126/science.1125572 if you use this in your work.
# The full dataset (along with many more) can be found here https://www.ntnu.edu/kavli/research/grid-cell-data
# The exact datafile being used is 8F6BE356-3277-475C-87B1-C7A977632DA7_1/11084-03020501_t2c1.mat
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/kl/5cmzc25n1_jdp8v6cklmpzm80000gn/T/ipykernel_1544/779656803.py in <module>
#       1 Env = Environment(params={'dimensionality':'2D'})
#       2 Ag = Agent(Env)
# ----> 3 Ag.import_trajectory(dataset="sargolini")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ratinabox-0.1-py3.9.egg/ratinabox/Agent.py in import_trajectory(self, times, positions, dataset)
#     352                         os.path.join(
#     353                         os.path.join(
# ...

# %%
fig, ax = plt.subplots(1,4,figsize=(12,6))
Ag.plot_trajectory(fig=fig,ax=ax[0],t_end=30)
Cs.plot_rate_map(method='groundtruth',fig=fig,ax=ax[1],chosen_neurons=1)
Cs.plot_rate_map(method='history',fig=fig,ax=ax[2],chosen_neurons=1)
Cs.plot_rate_timeseries(fig=fig,ax=ax[3],t_end=30)
# Out:
# (<Figure size 864x432 with 4 Axes>,
#  <AxesSubplot:xlabel='Time / min', ylabel='Neurons'>)

# %%
import ratinabox
from ratinabox.contribs import ValueNeuron
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kl/5cmzc25n1_jdp8v6cklmpzm80000gn/T/ipykernel_95404/2735760618.py in <module>
#       1 import ratinabox
# ----> 2 from ratinabox.contribs import ValueNeuron
#
# ~/Documents/RatInABox/example_scripts/../ratinabox/contribs/ValueNeuron.py in <module>
# ----> 1 class ValueNeuron(FeedForwardLayer):
#       2     """
#       3     Contributer: Tom George
#       4     Date: 21/07/2022
#       5
#
# NameError: name 'FeedForwardLayer' is not defined
